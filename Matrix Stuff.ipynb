# %%
import numpy as np

# %%
c = np.ones((2,1))
print(c)
c_star = np.conj(c).T
print(c_star)
# Out:
# [[1.]
#  [1.]]
# [[1. 1.]]

# %%
c * c_star
# Out:
# array([[1., 1.],
#        [1., 1.]])

# %%
c_star = np.transpose(c)

# %%
print(c_star)
# Out:
# [0.70710678 0.70710678]

# %%
print(c_star[:1,:1])
# Out:
# [[1.]]
