# %%
import colour
import numpy as np
from colour.plotting import *

# %%
RGB_in = np.array([1.161,  0.224, -0.013])
#RGB_in = np.array([[79, 2, 45], [87, 12, 67]])
#CIE = np.array([0.5600855610920833, 0.40505713590886977, 0.03485730299904705])

# %%
RGB = colour.models.eotf_inverse_sRGB(RGB_in / 255)
print(RGB)

# %%
plot_RGB_chromaticities_in_chromaticity_diagram_CIE1931(RGB_in)

# %%
RGB = np.random.random((2, 2, 3))
print(RGB)
plot_RGB_chromaticities_in_chromaticity_diagram_CIE1931(RGB, c="black")
# Out:
# [[[ 0.48716854  0.38879971  0.88190231]
#   [ 0.92244681  0.09173584  0.05951772]]
#
#  [[ 0.5053217   0.90845742  0.3776364 ]
#   [ 0.86510141  0.2054185   0.49114047]]]
# (<Figure size 640x640 with 1 Axes>,
#  <AxesSubplot:title={'center':'sRGB\nCIE 1931 2 Degree Standard Observer - CIE 1931 Chromaticity Diagram'}, xlabel='CIE x', ylabel='CIE y'>)

# %%
plot_RGB_chromaticities_in_chromaticity_diagram_CIE1931(RGB)
