3.386592368282329e-08,
2.477865429598836e-08,
1.430711486757394e-08,
3.2664162989420924e-07,
1.6764105841310063e-08,
2.3077108811889524e-08,
3.7827433595550157e-08,
9.104069467609664e-09,
4.968322256437421e-07,
8.772743476538052e-09,
3.64650364169523e-08,
2.2247262903180625e-08,
1.557163899811876e-08,
3.3376045795575795e-07,
1.3601312709373734e-08,
2.461188572915214e-08,
3.4078782603984764e-08,
1.0669408795406194e-08,
4.908270948705879e-07,
1.1383210376575416e-08,
3.455167026566107e-08,
2.624474175417473e-08,
1.3252420757313181e-08,
3.3361691622681173e-07,
1.8539954117137835e-08,
2.160944962351226e-08,
4.078102615112221e-08,
7.571264079657176e-09,
4.903951300885954e-07,
1.0177404022846443e-08,
3.788749390853163e-08,
2.527224114836307e-08,
1.587015041581214e-08,
3.242820379968074e-07,
1.635939711009105e-08,
2.6430454375085384e-08,
3.927292898882195e-08,
1.1322178499035545e-08,
4.35350014088915e-07,
9.594326476513506e-09,
4.605804821194263e-08,
2.4277626784222914e-08,
2.087138056550575e-08,
3.3777418322940455e-07,
1.8152615594178793e-08,
2.7611611758493524e-08,
4.219790954227155e-08,
1.191597725773812e-08,
6.615728051306212e-07,
4.202559684071682e-09,
2.195667395668221e-07,
1e-09,
2.292687059875339e-07,
0.])

# %%
opt_1_init = {
    "wavelength_list": [200e-9, 7000e-9, 2000],
    "Material_List": mat_start,
    "Thickness_List": MgF2_HfO2_start_from_opt_TE_10_RS_10_RE_80_init,
    "reflective_window_wn" : [2600, 3750],
    "transmissive_window_nm" : [300, 700],
    "transmission_efficiency_weight" : 0.1,
    "reflection_efficiency_weight" : 0.8,
    "reflection_selectivity_weight" : 0.1
}

# copy the base dictionary
opt_1 = opt_1_init.copy()

opt_2_init = opt_1_init.copy()
opt_2 = opt_1_init.copy()

opt_3_init = opt_1_init.copy()
opt_3 = opt_1_init.copy()

opt_4_init = opt_1_init.copy()
opt_4 = opt_1_init.copy()



# update the thickness lists
opt_1["Thickness_List"] = MgF2_HfO2_start_from_opt_TE_10_RS_10_RE_80_opt

opt_2_init["Thickness_List"] = MgF2_HfO2_scaled_opt_TE_10_RS_10_RE_80_init
opt_2["Thickness_List"] = MgF2_HfO2_scaled_opt_TE_10_RS_10_RE_80_opt

opt_3_init["Thickness_List"] = MgF2_HfO2_start_from_opt_TE_20_RS_20_RE_60_init
opt_3["Thickness_List"] = MgF2_HfO2_start_from_opt_TE_20_RS_20_RE_60_opt

opt_4_init["Thickness_List"] = MgF2_HfO2_scaled_opt_TE_20_RS_20_RE_60_init
opt_4["Thickness_List"] = MgF2_HfO2_scaled_opt_TE_20_RS_20_RE_60_opt

# create instances
plot_opt_1_init = sf.spectrum_factory('Tmm', opt_1_init)
plot_opt_1 = sf.spectrum_factory('Tmm', opt_1)

plot_opt_2_init = sf.spectrum_factory('Tmm', opt_2_init)
plot_opt_2 = sf.spectrum_factory('Tmm', opt_2)

plot_opt_3_init = sf.spectrum_factory('Tmm', opt_3_init)
plot_opt_3 = sf.spectrum_factory('Tmm', opt_3)

plot_opt_4_init = sf.spectrum_factory('Tmm', opt_4_init)
plot_opt_4 = sf.spectrum_factory('Tmm', opt_4)

# compute FOMS
plot_opt_1_init.compute_selective_mirror_fom()
print(plot_opt_1_init.selective_mirror_fom)
plot_opt_1.compute_selective_mirror_fom()
print(plot_opt_1.selective_mirror_fom)

plot_opt_2_init.compute_selective_mirror_fom()
print(plot_opt_2_init.selective_mirror_fom)
plot_opt_2.compute_selective_mirror_fom()
print(plot_opt_2.selective_mirror_fom)

plot_opt_3_init.compute_selective_mirror_fom()
print(plot_opt_3_init.selective_mirror_fom)
plot_opt_3.compute_selective_mirror_fom()
print(plot_opt_3.selective_mirror_fom)

plot_opt_4_init.compute_selective_mirror_fom()
print(plot_opt_4_init.selective_mirror_fom)
plot_opt_4.compute_selective_mirror_fom()
print(plot_opt_4.selective_mirror_fom)
# Out:
# 1.0
#  Your spectra have been computed! 😎
# 1.0
#  Your spectra have been computed! 😎
# 1.0
#  Your spectra have been computed! 😎
# 1.0
#  Your spectra have been computed! 😎
# 1.0
#  Your spectra have been computed! 😎
# 1.0
#  Your spectra have been computed! 😎
# 1.0
#  Your spectra have been computed! 😎
# 1.0
#  Your spectra have been computed! 😎
# 0.6146148558887311
# 0.7230328706725679
# 0.5666612120331442
# 0.7188377228723057
# 0.6146148558887311
# 0.7569640318087905
# 0.5666612120331442
# 0.7595807382114251

# %%
#plt.plot(plot_1.wavelength_array*1e9, plot_1.reflectivity_array, 'orange', label='Reflectivity')
print(F'eta_3 = {plot_opt_1.transmission_efficiency * 100}')
#print(plot_opt_1_init.transmission_efficiency * 100)

print(F'eta_2 = {plot_opt_1.reflection_efficiency * 100}')
#print(plot_opt_1_init.reflection_efficiency * 100)

print(F'eta_1 = {plot_opt_1.reflection_selectivity * 100}')
#print(plot_opt_1_init.reflection_selectivity * 100)

plt.plot(plot_opt_1.wavelength_array*1e9, plot_opt_1.transmissivity_array, 'blue', label='Opt. Transmissivity')
plt.plot(plot_opt_1.wavelength_array*1e9, plot_opt_1.emissivity_array, 'green', label='Opt. Absorptivity')
#plt.plot(plot_o.wavelength_array*1e9, plot_o.reflectivity_array, 'orange', linestyle="dashed", label='Reflectivity')
plt.plot(plot_opt_1.wavelength_array*1e9, plot_opt_1_init.transmissivity_array, 'blue', linestyle="dashed", label='Init. Transmissivity')
plt.plot(plot_opt_1.wavelength_array*1e9, plot_opt_1_init.emissivity_array, 'green', linestyle="dashed", label='Init. Absorptivity')
plt.plot(plot_opt_1.wavelength_array*1e9, plot_opt_1_init.transmissive_envelope, 'black', label="T envelope")
plt.legend(loc = 'best')
plt.xlim(200,700)
plt.savefig("MgF2_HfO2_Opt1_trans.png", dpi=150)
plt.show()


plt.plot(plot_opt_1.wavelength_array*1e9, plot_opt_1.reflectivity_array, 'orange', label='Opt. Reflectivity')
#plt.plot(plot_1.wavelength_array*1e9, plot_1.transmissivity_array, 'blue', label='Transmissivity')
plt.plot(plot_opt_1.wavelength_array*1e9, plot_opt_1.emissivity_array, 'green', label='Opt. Absorptivity')
plt.plot(plot_opt_1.wavelength_array*1e9, plot_opt_1_init.reflectivity_array, 'orange', linestyle="dashed", label='Init. Reflectivity')
#plt.plot(plot_o.wavelength_array*1e9, plot_o.transmissivity_array, 'blue', linestyle="dashed", label='Transmissivity')
plt.plot(plot_opt_1.wavelength_array*1e9, plot_opt_1_init.emissivity_array, 'green', linestyle="dashed", label='Init. Absorptivity')
plt.plot(plot_opt_1.wavelength_array*1e9, plot_opt_1_init.reflective_envelope, 'black', label="R envelope")
plt.legend(loc = 'best')
plt.xlim(2000,5000)
plt.savefig("MgF2_HfO2_Opt1_ref.png", dpi=150)
plt.show()
# Out:
# eta_3 = 87.63077227766651
# eta_2 = 69.79726868113158
# eta_1 = 77.02394894584856

# %%
#plt.plot(plot_1.wavelength_array*1e9, plot_1.reflectivity_array, 'orange', label='Reflectivity')
print(F'eta_3 = {plot_opt_2.transmission_efficiency * 100}')
#print(plot_opt_1_init.transmission_efficiency * 100)

print(F'eta_2 = {plot_opt_2.reflection_efficiency * 100}')
#print(plot_opt_1_init.reflection_efficiency * 100)

print(F'eta_1 = {plot_opt_2.reflection_selectivity * 100}')
#print(plot_opt_1_init.reflection_selectivity * 100)

plt.plot(plot_opt_1.wavelength_array*1e9, plot_opt_2.transmissivity_array, 'blue', label='Opt. Transmissivity')
plt.plot(plot_opt_1.wavelength_array*1e9, plot_opt_2.emissivity_array, 'green', label='Opt. Absorptivity')
#plt.plot(plot_o.wavelength_array*1e9, plot_o.reflectivity_array, 'orange', linestyle="dashed", label='Reflectivity')
plt.plot(plot_opt_1.wavelength_array*1e9, plot_opt_2_init.transmissivity_array, 'blue', linestyle="dashed", label='Init. Transmissivity')
plt.plot(plot_opt_1.wavelength_array*1e9, plot_opt_2_init.emissivity_array, 'green', linestyle="dashed", label='Init. Absorptivity')
plt.plot(plot_opt_1.wavelength_array*1e9, plot_opt_2_init.transmissive_envelope, 'black', label="T envelope")
plt.legend(loc = 'best')
plt.xlim(200,700)
plt.savefig("MgF2_HfO2_Opt2_trans.png", dpi=150)
plt.show()


plt.plot(plot_opt_1.wavelength_array*1e9, plot_opt_2.reflectivity_array, 'orange', label='Opt. Reflectivity')
#plt.plot(plot_1.wavelength_array*1e9, plot_1.transmissivity_array, 'blue', label='Transmissivity')
plt.plot(plot_opt_1.wavelength_array*1e9, plot_opt_2.emissivity_array, 'green', label='Opt. Absorptivity')
plt.plot(plot_opt_1.wavelength_array*1e9, plot_opt_2_init.reflectivity_array, 'orange', linestyle="dashed", label='Init. Reflectivity')
#plt.plot(plot_o.wavelength_array*1e9, plot_o.transmissivity_array, 'blue', linestyle="dashed", label='Transmissivity')
plt.plot(plot_opt_1.wavelength_array*1e9, plot_opt_2_init.emissivity_array, 'green', linestyle="dashed", label='Init. Absorptivity')
plt.plot(plot_opt_1.wavelength_array*1e9, plot_opt_2_init.reflective_envelope, 'black', label="R envelope")
plt.legend(loc = 'best')
plt.xlim(2000,5000)
plt.savefig("MgF2_HfO2_Opt2_ref.png", dpi=150)
plt.show()
# Out:
# eta_3 = 87.51264872876
# eta_2 = 69.41230364016194
# eta_1 = 76.02664502225016

# %%
#plt.plot(plot_1.wavelength_array*1e9, plot_1.reflectivity_array, 'orange', label='Reflectivity')
print(F'eta_3 = {plot_opt_3.transmission_efficiency * 100}')
#print(plot_opt_1_init.transmission_efficiency * 100)

print(F'eta_2 = {plot_opt_3.reflection_efficiency * 100}')
#print(plot_opt_1_init.reflection_efficiency * 100)

print(F'eta_1 = {plot_opt_3.reflection_selectivity * 100}')
#print(plot_opt_1_init.reflection_selectivity * 100)

plt.plot(plot_opt_1.wavelength_array*1e9, plot_opt_3.transmissivity_array, 'blue', label='Opt. Transmissivity')
plt.plot(plot_opt_1.wavelength_array*1e9, plot_opt_3.emissivity_array, 'green', label='Opt. Absorptivity')
#plt.plot(plot_o.wavelength_array*1e9, plot_o.reflectivity_array, 'orange', linestyle="dashed", label='Reflectivity')
plt.plot(plot_opt_1.wavelength_array*1e9, plot_opt_3_init.transmissivity_array, 'blue', linestyle="dashed", label='Init. Transmissivity')
plt.plot(plot_opt_1.wavelength_array*1e9, plot_opt_3_init.emissivity_array, 'green', linestyle="dashed", label='Init. Absorptivity')
plt.plot(plot_opt_1.wavelength_array*1e9, plot_opt_3_init.transmissive_envelope, 'black', label="T envelope")
plt.legend(loc = 'best')
plt.xlim(200,700)
plt.savefig("MgF2_HfO2_Opt3_trans.png", dpi=150)
plt.show()


plt.plot(plot_opt_1.wavelength_array*1e9, plot_opt_3.reflectivity_array, 'orange', label='Opt. Reflectivity')
#plt.plot(plot_1.wavelength_array*1e9, plot_1.transmissivity_array, 'blue', label='Transmissivity')
plt.plot(plot_opt_1.wavelength_array*1e9, plot_opt_3.emissivity_array, 'green', label='Opt. Absorptivity')
plt.plot(plot_opt_1.wavelength_array*1e9, plot_opt_3_init.reflectivity_array, 'orange', linestyle="dashed", label='Init. Reflectivity')
#plt.plot(plot_o.wavelength_array*1e9, plot_o.transmissivity_array, 'blue', linestyle="dashed", label='Transmissivity')
plt.plot(plot_opt_1.wavelength_array*1e9, plot_opt_3_init.emissivity_array, 'green', linestyle="dashed", label='Init. Absorptivity')
plt.plot(plot_opt_1.wavelength_array*1e9, plot_opt_3_init.reflective_envelope, 'black', label="R envelope")
plt.legend(loc = 'best')
plt.xlim(2000,5000)
plt.savefig("MgF2_HfO2_Opt3_ref.png", dpi=150)
plt.show()
# Out:
# eta_3 = 89.69634589980502
# eta_2 = 73.96153545334798
# eta_1 = 75.57540228220167

# %%
#plt.plot(plot_1.wavelength_array*1e9, plot_1.reflectivity_array, 'orange', label='Reflectivity')
print(F'eta_3 = {plot_opt_4.transmission_efficiency * 100}')
#print(plot_opt_1_init.transmission_efficiency * 100)

print(F'eta_2 = {plot_opt_4.reflection_efficiency * 100}')
#print(plot_opt_1_init.reflection_efficiency * 100)

print(F'eta_1 = {plot_opt_4.reflection_selectivity * 100}')
#print(plot_opt_1_init.reflection_selectivity * 100)

plt.plot(plot_opt_1.wavelength_array*1e9, plot_opt_4.transmissivity_array, 'blue', label='Opt. Transmissivity')
plt.plot(plot_opt_1.wavelength_array*1e9, plot_opt_4.emissivity_array, 'green', label='Opt. Absorptivity')
#plt.plot(plot_o.wavelength_array*1e9, plot_o.reflectivity_array, 'orange', linestyle="dashed", label='Reflectivity')
plt.plot(plot_opt_1.wavelength_array*1e9, plot_opt_4_init.transmissivity_array, 'blue', linestyle="dashed", label='Init. Transmissivity')
plt.plot(plot_opt_1.wavelength_array*1e9, plot_opt_4_init.emissivity_array, 'green', linestyle="dashed", label='Init. Absorptivity')
plt.plot(plot_opt_1.wavelength_array*1e9, plot_opt_4_init.transmissive_envelope, 'black', label="T envelope")
plt.legend(loc = 'best')
plt.xlim(200,700)
plt.savefig("MgF2_HfO2_Opt4_trans.png", dpi=150)
plt.show()


plt.plot(plot_opt_1.wavelength_array*1e9, plot_opt_4.reflectivity_array, 'orange', label='Opt. Reflectivity')
#plt.plot(plot_1.wavelength_array*1e9, plot_1.transmissivity_array, 'blue', label='Transmissivity')
plt.plot(plot_opt_1.wavelength_array*1e9, plot_opt_4.emissivity_array, 'green', label='Opt. Absorptivity')
plt.plot(plot_opt_1.wavelength_array*1e9, plot_opt_4_init.reflectivity_array, 'orange', linestyle="dashed", label='Init. Reflectivity')
#plt.plot(plot_o.wavelength_array*1e9, plot_o.transmissivity_array, 'blue', linestyle="dashed", label='Transmissivity')
plt.plot(plot_opt_1.wavelength_array*1e9, plot_opt_4_init.emissivity_array, 'green', linestyle="dashed", label='Init. Absorptivity')
plt.plot(plot_opt_1.wavelength_array*1e9, plot_opt_4_init.reflective_envelope, 'black', label="R envelope")
plt.legend(loc = 'best')
plt.xlim(2000,5000)
plt.savefig("MgF2_HfO2_Opt4_ref.png", dpi=150)
plt.show()
# Out:
# eta_3 = 89.72946541286737
# eta_2 = 74.22171994591635
# eta_1 = 76.07751323122692
