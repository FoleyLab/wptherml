 649.69081633,  22.20352533,  27.76623737, 134.26679671,  81.19273286]
) * 1e-9

opt_ref_selectiv_last = np.array([  1.,           3.40803334,   1.,          11.23343815,   1.,
 463.72735691,   1.,           9.01776872,  85.34326743,   1.,
 420.70014224,   1.,          93.16788807,  49.25398487,   1.,
 348.66780797,   1.,         109.41991892,   1.,          14.02186617,
 677.97073041,   1.,           1.,           1.,           1.,
 530.48398233,   5.88472304,   1.,          35.31641723,   1.,
 482.28562517,   1.,          65.66175593,  70.29868782,   1.,
 325.36310861,   1.,          81.4093415,    7.37500124,   1.,
 461.84606083,   1.,          77.1986959,   23.01928193,   1.,
 307.51176056,   1.,          74.68272466,   1.,          47.19018174,
 520.45190102,   1.14272588,   1.,           7.41723139,   1.,
 376.49357549,   1.,           2.56931366,   1.,           1.49718114,
 487.26524383,   4.82797717,   1.,          74.91021242,   1.,
 268.66343807,   1.,          48.50263251,  25.41922959,   1.,
 497.40757325, 137.86179389,   1.,         306.12182696,   5.98280415]) * 1e-9

mat_start = []
ctr = 0
for d in opt_ref_selectiv:
    if ctr==0:
        mat_start.append("Air")
    elif ctr % 2 == 1:
        mat_start.append("SiO2_udm_v2")
    else:
        mat_start.append("Al2O3")

    ctr += 1

mat_start[ctr-1] = 'Air'
        

print(len(mat_start))
# Out:
# 75

# %%
guess = np.array([0.00000000e+00,
7.8961E-08, 2.837E-08, 4.12007E-08, 4.048E-08, 1.43864E-08, 5.5398E-07, 1.57308E-08, 3.959E-08, 4.39954E-08, 1.439E-08, 1.0551E-06,
1.418E-08, 4.43554E-08, 3.953E-08, 1.59425E-08, 5.6418E-07, 1.391E-08, 4.29E-08, 4.17724E-08, 1.647E-08, 9.04325E-07, 1.627E-08, 4.19206E-08, 4.259E-08,
1.41323E-08, 7.8043E-07, 1.59214E-08, 3.959E-08, 4.45883E-08, 1.416E-08, 8.00748E-07, 1.369E-08, 4.52023E-08, 3.914E-08, 1.63025E-08, 7.7129E-07,
1.51062E-08, 4.048E-08, 4.35297E-08, 1.455E-08, 7.97637E-07, 1.351E-08, 4.46412E-08, 3.893E-08, 1.56038E-08, 5.525E-07, 1.57308E-08, 3.846E-08,
 4.44824E-08, 1.332E-08, 1.03724E-06, 1.441E-08, 4.23123E-08, 3.886E-08, 1.49898E-08, 7.5536E-07, 1.42911E-08, 4.067E-08, 4.20159E-08, 1.535E-08, 7.88429E-07,
 1.24E-08, 4.68325E-08, 3.734E-08, 1.73187E-08, 5.5042E-07, 1.46404E-08, 3.988E-08, 4.38049E-08, 1.372E-08, 1.04676E-06, 1.789E-08, 3.31977E-08, 1.5508E-07, 8.4561E-08,
0.00000000e+00]) * 0.55 
print(guess)
# Out:
# [0.0000000e+00 4.3428550e-08 1.5603500e-08 2.2660385e-08 2.2264000e-08
#  7.9125200e-09 3.0468900e-07 8.6519400e-09 2.1774500e-08 2.4197470e-08
#  7.9145000e-09 5.8030500e-07 7.7990000e-09 2.4395470e-08 2.1741500e-08
#  8.7683750e-09 3.1029900e-07 7.6505000e-09 2.3595000e-08 2.2974820e-08
#  9.0585000e-09 4.9737875e-07 8.9485000e-09 2.3056330e-08 2.3424500e-08
#  7.7727650e-09 4.2923650e-07 8.7567700e-09 2.1774500e-08 2.4523565e-08
#  7.7880000e-09 4.4041140e-07 7.5295000e-09 2.4861265e-08 2.1527000e-08
#  8.9663750e-09 4.2420950e-07 8.3084100e-09 2.2264000e-08 2.3941335e-08
#  8.0025000e-09 4.3870035e-07 7.4305000e-09 2.4552660e-08 2.1411500e-08
#  8.5820900e-09 3.0387500e-07 8.6519400e-09 2.1153000e-08 2.4465320e-08
#  7.3260000e-09 5.7048200e-07 7.9255000e-09 2.3271765e-08 2.1373000e-08
#  8.2443900e-09 4.1544800e-07 7.8601050e-09 2.2368500e-08 2.3108745e-08
#  8.4425000e-09 4.3363595e-07 6.8200000e-09 2.5757875e-08 2.0537000e-08
# ...

# %%
plot_ref_selectivity = {
    "wavelength_list": [300e-9, 6000e-9, 1000],
    "Material_List": mat_start,
    "Thickness_List": opt_ref_selectiv,
    "reflective_window_wn" : [2600, 3750],
    "transmissive_window_nm" : [300, 700],
 }

plot_ref_selectivity_last = {
    "wavelength_list": [300e-9, 6000e-9, 1000],
    "Material_List": mat_start,
    "Thickness_List": opt_ref_selectiv_last,
    "reflective_window_wn" : [2600, 3750],
    "transmissive_window_nm" : [300, 700],
 }

plot_ref_efficiency = {
    "wavelength_list": [300e-9, 6000e-9, 1000],
    "Material_List": mat_start,
    "Thickness_List": opt_ref_efficiency_last,
    "reflective_window_wn" : [2600, 3750],
    "transmissive_window_nm" : [300, 700],
}

plot_balance = {
    "wavelength_list": [300e-9, 6000e-9, 1000],
    "Material_List": mat_start,
    "Thickness_List": opt_balance_last,
    "reflective_window_wn" : [2600, 3750],
    "transmissive_window_nm" : [300, 700],
}

# the top-level driver class is called "SpectrumFactory" - create an instance of it
sf = wptherml.SpectrumFactory()  

ref_selective_opt_res = sf.spectrum_factory('Tmm', plot_ref_selectivity)
ref_selective_last_res = sf.spectrum_factory('Tmm', plot_ref_selectivity_last)
ref_efficiency_res = sf.spectrum_factory('Tmm', plot_ref_efficiency)
ref_balance_res = sf.spectrum_factory('Tmm', plot_balance)
# Out:
# 1.0
#  Your spectra have been computed! 😎
# 1.0
#  Your spectra have been computed! 😎
# 1.0
#  Your spectra have been computed! 😎
# 1.0
#  Your spectra have been computed! 😎

# %%
plt.plot(ref_selective_opt_res.wavelength_array*1e9, ref_selective_opt_res.reflectivity_array, 'red', label='$\eta_1$ Opt')
plt.plot(ref_selective_opt_res.wavelength_array*1e9, ref_selective_last_res.reflectivity_array, 'orange', label='$\eta_1$ Near Opt')
plt.plot(ref_selective_opt_res.wavelength_array*1e9, ref_efficiency_res.reflectivity_array, 'green', label="$\eta_2$ Near Opt")
plt.plot(ref_selective_opt_res.wavelength_array*1e9, ref_balance_res.reflectivity_array, 'blue', label="$\eta_1 + \eta_2 + \eta_3$ Near Opt")
plt.plot(ref_selective_opt_res.wavelength_array*1e9, ref_selective_opt_res.reflective_envelope, 'black', label="$\Pi_R$")
plt.legend(loc = 'best')
plt.xlim(2000,5000)
plt.savefig("reflectivity_SiO2Al2O3.png", dpi=150)
plt.show()

plt.plot(ref_selective_opt_res.wavelength_array*1e9, ref_selective_opt_res.transmissivity_array, 'red', label='$\eta_1$ Opt')
plt.plot(ref_selective_opt_res.wavelength_array*1e9, ref_selective_last_res.transmissivity_array, 'orange', label='$\eta_1$ Near Opt')
plt.plot(ref_selective_opt_res.wavelength_array*1e9, ref_efficiency_res.transmissivity_array, 'green', label="$\eta_2$ Near Opt")
plt.plot(ref_selective_opt_res.wavelength_array*1e9, ref_balance_res.transmissivity_array, 'blue', label="$\eta_1 + \eta_2 + \eta_3$ Near Opt")
plt.plot(ref_selective_opt_res.wavelength_array*1e9, ref
 588.69320641,  10.46226187,  33.06847348,  24.8334307,   12.742923, 
 346.35214035,  15.40184835,  24.90028131,  37.02939053,   9.91520258,
 453.53513825,   9.34699006,  38.60246237,  23.77574401,  17.00899511,
 332.3609942,   15.65280798,  25.69089368,  38.42730944,  10.60190855,
 542.99362071,  10.61775051,  38.76782655,  25.36269063,  15.418318,
 380.71349209,  15.15168277,  25.87562255,  38.24033636,  10.98143762,
 523.50263155,  10.56246065,  40.67015481,  25.59852547,  16.28181738,
 368.34573809,  14.56486997,  26.16253567,  38.4975419,   10.62190858,
 528.71806818,   9.74289675,  39.02753226,  24.17072396,  15.43943966,
 330.58372533,  14.7235226,   27.92713852,  38.18843285,  11.51081945,
 439.77968112,  11.430953,    40.79199568,  27.79751689,  16.82743109,
 342.75558414,  18.73324815,  25.47896005,  41.93244253,   9.68226992,
 671.61432608,  16.35352182,  26.60320247, 107.61386095,  87.82928827,
0.0]) * 1e-9 * 0.92

mat_start = []
ctr = 0
for d in MgF2_HfO2_DBR:
    if ctr==0:
        mat_start.append("Air")
    elif ctr % 2 == 1:
        mat_start.append("MgF2")
    else:
        mat_start.append("HfO2_udm")

    ctr += 1

mat_start[ctr-1] = 'Air'
        

print(len(mat_start))  
print(mat_start)


opt_1 = {
    "wavelength_list": [200e-9, 6000e-9, 1000],
    "Material_List": mat_start,
    "Thickness_List": MgF2_Opt_start_from_SiO2HfO2,
    "reflective_window_wn" : [2600, 3750],
    "transmissive_window_nm" : [300, 700],
}

opt_2 = {
    "wavelength_list": [200e-9, 6000e-9, 1000],
    "Material_List": mat_start,
    "Thickness_List": MgF2_Opt_scaled,
    "reflective_window_wn" : [2600, 3750],
    "transmissive_window_nm" : [300, 700],
}

opt_o = {
    "wavelength_list": [200e-9, 6000e-9, 1000],
    "Material_List": mat_start,
    "Thickness_List": MgF2_HfO2_DBR,
    "reflective_window_wn" : [2600, 3750],
    "transmissive_window_nm" : [300, 700],
}



plot_1 = sf.spectrum_factory('Tmm', opt_1)
plot_2 = sf.spectrum_factory('Tmm', opt_2)
plot_o = sf.spectrum_factory('Tmm', opt_o)
# Out:
# 77
# ['Air', 'MgF2', 'HfO2_udm', 'MgF2', 'HfO2_udm', 'MgF2', 'HfO2_udm', 'MgF2', 'HfO2_udm', 'MgF2', 'HfO2_udm', 'MgF2', 'HfO2_udm', 'MgF2', 'HfO2_udm', 'MgF2', 'HfO2_udm', 'MgF2', 'HfO2_udm', 'MgF2', 'HfO2_udm', 'MgF2', 'HfO2_udm', 'MgF2', 'HfO2_udm', 'MgF2', 'HfO2_udm', 'MgF2', 'HfO2_udm', 'MgF2', 'HfO2_udm', 'MgF2', 'HfO2_udm', 'MgF2', 'HfO2_udm', 'MgF2', 'HfO2_udm', 'MgF2', 'HfO2_udm', 'MgF2', 'HfO2_udm', 'MgF2', 'HfO2_udm', 'MgF2', 'HfO2_udm', 'MgF2', 'HfO2_udm', 'MgF2', 'HfO2_udm', 'MgF2', 'HfO2_udm', 'MgF2', 'HfO2_udm', 'MgF2', 'HfO2_udm', 'MgF2', 'HfO2_udm', 'MgF2', 'HfO2_udm', 'MgF2', 'HfO2_udm', 'MgF2', 'HfO2_udm', 'MgF2', 'HfO2_udm', 'MgF2', 'HfO2_udm', 'MgF2', 'HfO2_udm', 'MgF2', 'HfO2_udm', 'MgF2', 'HfO2_udm', 'MgF2', 'HfO2_udm', 'MgF2', 'Air']
# 1.0
#  Your spectra have been computed! 😎
# 1.0
#  Your spectra have been computed! 😎
# 1.0
#  Your spectra have been computed! 😎

# %%
#plt.plot(plot_1.wavelength_array*1e9, plot_1.reflectivity_array, 'orange', label='Reflectivity')
plt.plot(plot_1.wavelength_array*1e9, plot_1.transmissivity_array, 'blue', label='Transmissivity')
plt.plot(plot_1.wavelength_array*1e9, plot_1.emissivity_array, 'green', label='Absorptivity')
#plt.plot(plot_o.wavelength_array*1e9, plot_o.reflectivity_array, 'orange', linestyle="dashed", label='Reflectivity')
plt.plot(plot_o.wavelength_array*1e9, plot_o.transmissivity_array, 'blue', linestyle="dashed", label='Transmissivity')
plt.plot(plot_o.wavelength_array*1e9, plot_o.emissivity_array, 'green', linestyle="dashed", label='Absorptivity')
plt.plot(plot_1.wavelength_array*1e9, plot_1.transmissive_envelope, 'black', label="T envelope")
plt.legend(loc = 'best')
plt.xlim(200,700)
plt.show()


plt.plot(plot_1.wavelength_array*1e9, plot_1.reflectivity_array, 'orange', label='Reflectivity')
#plt.plot(plot_1.wavelength_array*1e9, plot_1.transmissivity_array, 'blue', label='Transmissivity')
plt.plot(plot_1.wavelength_array*1e9, plot_1.emissivity_array, 'green', label='Absorptivity')
plt.plot(plot_o.wavelength_array*1e9, plot_o.reflectivity_array, 'orange', linestyle="dashed", label='Reflectivity')
#plt.plot(plot_o.wavelength_array*1e9, plot_o.transmissivity_array, 'blue', linestyle="dashed", label='Transmissivity')
plt.plot(plot_o.wavelength_array*1e9, plot_o.emissivity_array, 'green', linestyle="dashed", label='Absorptivity')
plt.plot(plot_1.wavelength_array*1e9, plot_1.reflective_envelope, 'black', label="T envelope")
plt.legend(loc = 'best')
plt.xlim(2000,5000)
plt.show()

# %%
plt.plot(guess_mgf2_hfo2.wavelength_array*1e9, guess_mgf2_hfo2.reflectivity_array, 'orange', label='Reflectivity')
plt.plot(guess_mgf2_hfo2.wavelength_array*1e9, guess_mgf2_hfo2.transmissivity_array, 'blue', label='Transmissivity')
plt.plot(guess_mgf2_hfo2.wavelength_array*1e9, guess_mgf2_hfo2.emissivity_array, 'green', label='Absorptivity')
plt.plot(guess_mgf2_hfo2.wavelength_array*1e9, guess_mgf2_hfo2.transmissive_envelope, 'black', label="T envelope")
plt.legend(loc = 'best')
plt.xlim(200,700)
plt.show()

plt.plot(guess_mgf2_hfo2.wavelength_array*1e9, guess_mgf2_hfo2.reflectivity_array, 'orange', label='Reflectivity')
plt.plot(guess_mgf2_hfo2.wavelength_array*1e9, guess_mgf2_hfo2.transmissivity_array, 'blue', label='Transmissivity')
plt.plot(guess_mgf2_hfo2.wavelength_array*1e9, guess_mgf2_hfo2.emissivity_array, 'green', label='Absorptivity')
plt.plot(guess_mgf2_hfo2.wavelength_array*1e9, guess_mgf2_hfo2.reflective_envelope, 'black', label="T envelope")
plt.legend(loc = 'best')
plt.xlim(2000,5000)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 plt.plot(guess_mgf2_hfo2.wavelength_array*1e9, guess_mgf2_hfo2.reflectivity_array, 'orange', label='Reflectivity')
#       2 plt.plot(guess_mgf2_hfo2.wavelength_array*1e9, guess_mgf2_hfo2.transmissivity_array, 'blue', label='Transmissivity')
#       3 plt.plot(guess_mgf2_hfo2.wavelength_array*1e9, guess_mgf2_hfo2.emissivity_array, 'green', label='Absorptivity')
#
# NameError: name 'guess_mgf2_hfo2' is not defined

# %%
#results = ts.optimize_basin_hopping()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 results = ts.optimize_basin_hopping()
#
# NameError: name 'ts' is not defined

# %%
print(results)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(results)
#
# NameError: name 'results' is not defined

# %%
d_start_1 = [0.00000000e+00, 4.4754E-08, 1.82725E-08, 2.3352E-08, 2.60723E-08, 
           8.154E-09, 3.56807E-07, 8.916E-09, 2.54991E-08, 2.4936E-08, 9.26829E-09, 
           6.06372E-07, 9.13304E-09, 2.514E-08, 2.54604E-08, 9.036E-09, 3.63376E-07, 
           7.884E-09, 2.7631E-08, 2.3676E-08, 1.0608E-08, 5.1972E-07, 1.04792E-08,
           2.376E-08, 2.74313E-08, 8.01E-09, 5.02658E-07, 9.024E-09, 2.54991E-08, 2.5272E-08, 9.12015E-09,
 3.70105624e-07, 1.81730516e-08, 2.01997540e-08, 3.51182294e-08,
 8.53239379e-09, 4.58629366e-07, 9.90613835e-09, 3.55219573e-08,
 2.22354202e-08, 1.64977593e-08, 3.40689828e-07, 1.17511343e-08,
 2.71029256e-08, 3.12952869e-08, 1.27045686e-08, 5.13310343e-07,
 1.30767640e-08, 3.13865860e-08, 2.82497608e-08, 1.32763917e-08,
 3.31147751e-07, 1.89529060e-08, 2.31797321e-08, 3.83293630e-08,
 1.05687674e-08, 4.38740172e-07, 1.23511008e-08, 3.66630467e-08,
 2.60933699e-08, 1.67499716e-08, 3.31714228e-07, 1.76918913e-08,
 2.68345405e-08, 3.81204418e-08, 1.22073384e-08, 5.99421385e-07,
 1.22425376e-08, 5.10268799e-08, 1.24743822e-08, 4.01629952e-07,
 0.00000000e+00]


mat_start = []
ctr = 0
for d in d_start_1:
    if ctr==0:
        mat_start.append("Air")
    elif ctr % 2 == 1:
        mat_start.append("SiO2")
    else:
        mat_start.append("Al2O3")

    ctr += 1

mat_start[ctr-1] = 'Air'
        

print(len(mat_start))

# %%
d_opt = np.array([0., 297.19190971,   1.77824734, 146.13931006,  15.34374935,  24.18455267,
 277.71851659,  26.40072944,  12.70836282,  46.58836313,   7.51893364,
 701.71862049,  11.15682872,  22.76916687, 141.47719782,   2.1434174,
 453.09533235,   3.04422321,  84.60687477,  25.35182884,  13.09132895,
 574.46512586,   1.,         116.52511489,   2.77408119,  98.1713121,
 257.79531168,   1.,          12.60939387,   1.,          17.68619604,
   1.,          35.62524689,   1.,          38.08054492,   1.,
 314.19130786,  97.7830044,    4.86331428, 130.97462777,   1.,
 563.75455166,  13.84814551,  17.5228161,  117.62872491,   1.,
 465.57240259,   7.23079107,  81.37283052,  68.87939446,   1.30347893,
 681.70945381,   8.63947304,  36.30584112,  16.39976773,  19.4618424,
 594.31647571,   7.34069959,  80.95814661, 114.63445954,   3.10813685,
 578.51961763,   4.55599933, 117.0531905,   16.14098396,  19.8062105,
 202.5298761,  21.37114374,  24.91414263,  28.45478594,  17.61330257,
 446.38358132,   1.,           1.,          1.,           1., 0])


        

print(len(mat_start))  

print(len(d_opt))
d_plot = d_opt * 1e-9

start_args = {
    "wavelength_list": [200e-9, 7000e-9, 5000],
    "Material_List": mat_start,
    "Thickness_List": d_plot,
    "reflective_window_wn" : [2000, 2400],
    "transmissive_window_nm" : [350, 700],
 }

test = sf.spectrum_factory('Tmm', start_args)
plt.plot(test.wavelength_array*1e9, test.reflectivity_array, 'blue', label='Reflectivity')
plt.plot(test.wavelength_array*1e9, test.transmissivity_array, 'red', label='Transmissivity')
plt.legend(loc = 'best')
plt.xlim(300,7000)
plt.show()


#test = sf.spectrum_factory('Tmm', start_args)
plt.plot(test.wavelength_array*1e9, test.reflectivity_array, 'blue', label='Reflectivity')
plt.plot(test.wavelength_array*1e9, test.transmissivity_array, 'red', label='Transmissivity')
plt.legend(loc = 'best')
plt.xlim(2500,4000)
plt.show()

# %%
ts = sf.spectrum_factory("Opt", start_args)

# %%
ts.optimize_basin_hopping()

# %%
_x_range = 1.0 
print(_x_range)
print(int(_x_range))
np.random.randint(-int(_x_range), int(_x_range))
