# %%
import psi4
import numpy as np
from scipy.interpolate import InterpolatedUnivariateSpline
from numpy import linalg as LA
from psi4.driver.procrouting.response.scf_response import tdscf_excitations

# %%
psi4.set_options({
    'basis':'6-311G**'
})

m_MTTM = psi4.geometry(""" 
C       -2.7479020000     -0.1996430000      4.4532200000                 
C       -3.6493240000     -1.2936530000      4.4705740000                 
C       -5.0403930000     -1.1313600000      4.4944100000                 
C       -5.5617650000      0.1566690000      4.5073100000                 
C       -4.7058100000      1.2595420000      4.4937910000                 
C       -3.3085010000      1.0999930000      4.4660360000                 
C       -1.2691210000     -0.4367420000      4.4263950000                 
H       -3.2801860000     -2.3164380000      4.4670090000                 
C       -5.9513350000     -2.3233690000      4.5062930000                 
H       -6.6379080000      0.3138960000      4.5273950000                 
H       -5.1673620000      2.2417010000      4.5034840000                 
O       -2.4442970000      2.1651260000      4.4438740000                 
C       -2.9846160000      3.4781340000      4.4848680000                 
H       -3.5983070000      3.6801830000      3.6006650000                 
H       -2.1499670000      4.1855670000      4.4766080000                 
H       -3.5510930000      3.6454160000      5.4071340000                 
H       -5.3862580000     -3.2616750000      4.4868870000                 
H       -6.6029510000     -2.3096000000      3.6270090000                 
H       -6.5640310000     -2.3218470000      5.4130850000                 
N       -0.3208090000      0.4906670000      4.4897400000                 
S       -0.6579110000     -2.0789920000      4.3007970000                 
C        0.9412010000     -1.4525480000      4.3540490000                 
C        0.9050300000     -0.1009920000      4.4496330000                 
S        2.5316070000      0.5002020000      4.5008120000                 
N        2.1495030000     -2.0554450000      4.3188810000                 
C        3.1133620000     -1.1539480000      4.4041590000                 
C        4.5701640000     -1.4889630000      4.4172450000                 
C        5.5611830000     -0.4817150000      4.4010380000                 
C        6.9318760000     -0.7871480000      4.4068500000                 
C        7.3297910000     -2.1226000000      4.4241430000                 
C        6.3779260000     -3.1399930000      4.4411130000                 
C        5.0082420000     -2.8410840000      4.4409380000                 
H        5.2805370000      0.5687350000      4.3812770000                 
C        7.9712090000      0.2952990000      4.3936810000                 
H        8.3863380000     -2.3823760000      4.4261720000                 
H        6.7379430000     -4.1633360000      4.4566540000                 
O        4.0440490000     -3.8161550000      4.4717430000                 
C        4.4308210000     -5.1800140000      4.4731430000                 
H        4.9877380000     -5.4354560000      3.5661610000                 
H        3.5177990000     -5.7837250000      4.4822110000                 
H        5.0001490000     -5.4268020000      5.3746600000                 
H        7.5174260000      1.2912770000      4.3872970000                 
H        8.5976270000      0.2043630000      3.5003270000                 
H        8.6034920000      0.2197330000      5.2844870000                         
""")

psi4.set_options({
    'save_jk': True,
    })  


#Calculate energy and wavefunction of ground state
e, wfn = psi4.energy("CAM-b3lyp/6-311G**", return_wfn=True, molecule=m_MTTM)

res = tdscf_excitations(wfn, states=1, triplets = "NONE")

mu = [r["ELECTRIC DIPOLE TRANSITION MOMENT (LEN)"] for r in res]
# Out:
# Scratch directory: /tmp/
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  5, 4, 3
#     Auxiliary basis highest AM E, G, H:  6, 5, 4
#     Onebody   basis highest AM E, G, H:  6, 5, 4
#     Solid Harmonics ordering:            gaussian
#
# *** tstart() called on CHEMYM0V4HTALT
# *** at Tue May 30 14:03:51 2023
#
#    => Loading Basis Set <=
#
#     Name: 6-311G**
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1
1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A =      0.01469  B =      0.00245  C =      0.00211 [cm^-1]
#   Rotational constants: A =    440.53422  B =     73.58145  C =     63.17305 [MHz]
#   Nuclear repulsion = 2438.650638694165991
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 200
#   Nalpha       = 100
#   Nbeta        = 100
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is DF.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-06
#   Density threshold  = 1.00e-06
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: 6-311G**
#     Blend: 6-311G**
#     Number of shells: 288
#     Number of basis functions: 592
#     Number of Cartesian functions: 618
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#   ==> DFT Potential <==
#
#    => LibXC <=
#
#     Version 6.1.0
#     S. Lehtola, C. Steigemann, M. J.T. Oliveira, and M. A.L. Marques.,  SoftwareX 7, 1–5 (2018) (10.1016/j.softx.2017.11.002)
#
#    => Composite Functional: CAM-B3LYP <=
#
#     CAM-B3LYP Hyb-GGA Exchange-Correlation Functional
#
#     T. Yanai, D. P. Tew, and N. C. Handy.,  Chem. Phys. Lett. 393, 51 (2004) (10.1016/j.cplett.2004.06.011)
#
#     Deriv               =              1
#     GGA                 =           TRUE
#     Meta                =          FALSE
#
#     Exchange Hybrid     =           TRUE
#     MP2 Hybrid          =          FALSE
#
#    => Exchange Functionals <=
#
#     0.3500         Becke 88 [omega = 0.3300]
#     0.4600   Short-range recipe for B88 functional - erf [omega = 0.3300]
#
#    => Exact (HF) Exchange <=
#
#     0.4600            HF,LR [omega = 0.3300]
#     0.1900               HF
#
#    => Correlation Functionals <=
#
#     0.1900   Vosko, Wilk & Nusair (VWN5)
#     0.8100   Lee, Yang & Parr
#
#    => LibXC Density Thresholds  <==
#
#     XC_HYB_GGA_XC_CAM_B3LYP:  1.00E-14
#
#    => Molecular Quadrature <=
#
#     Radial Scheme          =       TREUTLER
#     Pruning Scheme         =           NONE
#     Nuclear Scheme         =       TREUTLER
#
#     Blocking Scheme        =         OCTREE
#     BS radius alpha        =              1
#     Pruning alpha          =              1
#     Radial Points          =             75
#     Spherical Points       =            302
#     Total Points           =         910106
#     Total Blocks           =           6570
#     Max Points             =            256
#     Max Functions          =            305
#     Weights Tolerance      =       1.00E-15
#
#    => Loading Basis Set <=
#
#     Name: (6-311G** AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1-7, 9, 13, 22-23, 26-32, 34, 38  entry C          line   125 file /Users/ptolley1/miniforge3/envs/work/share/psi4/basis/cc-pvtz-jkfit.gbs
#     atoms 8, 10-11, 14-19, 33, 35-36, 39-44 entry H          line    51 file /Users/ptolley1/miniforge3/envs/work/share/psi4/basis/cc-pvtz-jkfit.gbs
#     atoms 12, 37                            entry O          line   229 file /Users/ptolley1/miniforge3/envs/work/share/psi4/basis/cc-pvtz-jkfit.gbs
#     atoms 20, 25                            entry N          line   177 file /Users/ptolley1/miniforge3/envs/work/share/psi4/basis/cc-pvtz-jkfit.gbs
#     atoms 21, 24                            entry S          line   613 file /Users/ptolley1/miniforge3/envs/work/share/psi4/basis/cc-pvtz-jkfit.gbs
#   ==> Integral Setup <==
#
#   ==> DiskDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                 Yes
#     Omega:               3.300E-01
#     OpenMP threads:              1
#     Integrals threads:           1
#     Memory [MiB]:              337
#     Algorithm:                Disk
#     Integral Cache:           NONE
#     Schwarz Cutoff:          1E-12
#     Fitting Condition:       1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (6-311G** AUX)
#     Blend: CC-PVTZ-JKFIT
#     Number of shells: 854
#     Number of basis functions: 2678
#     Number of Cartesian functions: 3224
#     Spherical Harmonics?: true
#     Max angular momentum: 4
#
#   Cached 0.8% of DFT collocation blocks in 0.042 [GiB].
#
#   Minimum eigenvalue in the overlap matrix is 1.5825109230E-04.
#   Reciprocal condition number of the overlap matrix is 2.3280723779E-05.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A        592     592
#    -------------------------
#     Total     592     592
#    -------------------------
#
#   ==> Iterations <==
#
#                            Total Energy        Delta E     RMS |[F,P]|
#
#    @DF-RKS iter SAD: -1828.60764431741086   -1.82861e+03   0.00000e+00
#    @DF-RKS iter   1: -1828.02012883737098    5.87515e-01   2.44264e-03 ADIIS/DIIS
#    @DF-RKS iter   2: -1828.14786725337240   -1.27738e-01   2.26094e-03 ADIIS/DIIS
#    @DF-RKS iter   3: -1828.96036692024131   -8.12500e-01   5.76548e-04 ADIIS/DIIS
#    @DF-RKS iter   4: -1829.00549088668049   -4.51240e-02   1.63704e-04 ADIIS/DIIS
#    @DF-RKS iter   5: -1829.00970556104471   -4.21467e-03   5.46375e-05 DIIS
#    @DF-RKS iter   6: -1829.01018780433833   -4.82243e-04   1.85094e-05 DIIS
#    @DF-RKS iter   7: -1829.01025699121510   -6.91869e-05   4.97834e-06 DIIS
#    @DF-RKS iter   8: -1829.01026485790862   -7.86669e-06   1.67136e-06 DIIS
#    @DF-RKS iter   9: -1829.01026594933728   -1.09143e-06   7.83349e-07 DIIS
#    @DF-RKS iter  10: -1829.01026609019914   -1.40862e-07   3.21004e-07 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#    Electrons on quadrature grid:
#       Ntotal   
#      491A      3.114150   492A      3.121769   493A      3.122115
#      494A      3.126304   495A      3.133787   496A      3.135663
#      497A      3.203500   498A      3.228005   499A      3.232428
#      500A      3.245507   501A      3.258418   502A      3.262063
#      503A      3.270692   504A      3.314516   505A      3.320720
#      506A      3.325178   507A      3.377602   508A      3.384430
#      509A      3.424605   510A      3.427632   511A      3.440433
#      512A      3.452403   513A      3.465919   514A      3.479993
#      515A      3.558117   516A      3.571193   517A      3.597346
#      518A      3.623310   519A      3.626161   520A      3.694854
#      521A      3.699571   522A      3.707805   523A      3.713906
#      524A      3.850890   525A      3.852119   526A      3.853188
#      527A      3.855514   528A      3.873676   529A      3.876489
#      530A      3.878532   531A      3.880707   532A      3.905822
#      533A      3.914021   534A      3.929586   535A      4.076135
#      536A      4.081478   537A      4.174698   538A      4.184243
#      539A      4.195191   540A      4.203167   541A      4.219514
#      542A      4.240530   543A      4.305628   544A      4.313631
#      545A      4.404272   546A      4.407164   547A      4.486807
#      548A      4.559142   549A      4.907128   550A      4.908140
#      551A      4.987261   552A      4.993486   553A      5.086771
#      554A      5.263723   555A      5.433698   556A      5.452535
#      557A      5.839469   558A      5.848061   559A      7.897171
#      560A      7.921977   561A     17.261077   562A     17.280922
#      563A     17.493859   564A     17.523654   565A     17.564918
#      566A     17.609034   567A     23.547864   568A     23.565660
#      569A     23.702931   570A     23.808247   571A     23.819803
#      572A     23.910613   573A     23.918974   574A     23.931653
#      575A     23.935035   576A     23.945180   577A     23.958287
#      578A     23.991425   579A     23.992409   580A     24.080590
#      581A     24.081253   582A     24.120450   583A     24.121453
#      584A     24.168969   585A     24.216149   586A     24.216616
#      587A     35.663474   588A     35.715066   589A     49.981114
#      590A     49.984095   591A    188.944191   592A    188.966232
#
#     Final Occupation by Irrep:
#               A
#     DOCC [   100 ]
#     NA   [   100 ]
#     NB   [   100 ]
#
#   @DF-RKS Final Energy: -1829.01026609019914
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =           2438.6506386941659912
#     One-Electron Energy =               -7352.6770477081354329
#     Two-Electron Energy =                3230.6355698516422308
#     DFT Exchange-Correlation Energy =    -145.6194269278714444
#     Empirical Dispersion Energy =           0.0000000000000000
#     VV10 Nonlocal Energy =                  0.0000000000000000
#     Total Energy =                      -1829.0102660901991385
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :          0.3245627           -0.3923810           -0.0678183
#  Dipole Y            :          1.2910064           -1.4011918           -0.1101855
#  Dipole Z            :         -0.4345972            0.4709618            0.0363646
#  Magnitude           :                                                    0.1343970
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on CHEMYM0V4HTALT at Tue May 30 14:10:04 2023
# Module time:
# 	user time   =     351.98 seconds =       5.87 minutes
# 	system time =      14.26 seconds =       0.24 minutes
# 	total time  =        373 seconds =       6.22 minutes
# Total time:
# 	user time   =     351.98 seconds =       5.87 minutes
# 	system time =      14.26 seconds =       0.24 minutes
# 	total time  =        373 seconds =       6.22 minutes
#
# ******************************************************************************************
# **********                               WARNING                                **********
# **********       The names of excited state variables changed between 1.5       **********
# **********     and 1.6. For a quick solution, remove the symmetry specifier     **********
# **********   from the variable name. For full details, see 'Notes on Psivars'   **********
# **********                        in the documentation.                         **********
# ******************************************************************************************
#
#
#
#          ---------------------------------------------------------
#                          TDSCF excitation energies
#                  by Andrew M. James and Daniel G. A. Smith
#          ---------------------------------------------------------
#
#   ==> Options <==
#
#      Residual threshold  : 1.0000e-04
#      Initial guess       : denominators
#      Reference           : RHF
#      Solver type         : RPA (Hamiltonian)
#
#
#   ==> Requested Excitations <==
#
#       1 singlet states with A symmetry
#   ==> Seeking the lowest 1 singlet states with A symmetry
#
#                         Generalized Hamiltonian Solver
#                               By Andrew M. James
#
#   ==> Options <==
#
#     Max number of iterations        = 60
#     Eigenvector tolerance           = 1.0000e-04
#     Max number of expansion vectors = 200
#
#   => Iterations <=
#                               Max[D[value]]     Max[|R|]   # vectors
#   HamiltonianSolver iter   1:   1.54409e-01  2.42886e-01      4
#   HamiltonianSolver iter   2:   1.86822e-02  8.39614e-02      6
#   HamiltonianSolver iter   3:   1.85465e-03  3.62707e-02      8
#   HamiltonianSolver iter   4:   4.40218e-04  1.43548e-02     10
#   HamiltonianSolver iter   5:   5.40912e-05  5.59360e-03     12
#   HamiltonianSolver iter   6:   6.65310e-06  2.05249e-03     14
#   HamiltonianSolver iter   7:   1.27233e-06  7.59736e-04     16
#   HamiltonianSolver iter   8:   2.00553e-07  3.03284e-04     18
#   HamiltonianSolver iter   9:   2.14871e-08  1.19715e-04     20
#   HamiltonianSolver iter  10:   2.69999e-09  3.96485e-05     22      Converged
#
# ******************************************************************************************
# **********                               WARNING                                **********
# **********  Length-gauge rotatory strengths are **NOT** gauge-origin invariant  **********
# ******************************************************************************************
#
#                                     Excitation Energy         Total Energy        Oscillator Strength             Rotatory Strength
#      #   Sym: GS->ES (Trans)        au              eV              au          au (length)    au (velocity)    au (length)    au (velocity)
#     ---- -------------------- --------------- --------------- --------------- --------------- --------------- --------------- ---------------
#      1        A->A (1 A)       0.13337         3.62916        -1828.87690      1.0806          1.0479          0.0232          0.0234
#
#
#
# Contributing excitations and de-excitations
# Only contributions with abs(coeff) > 1.00e-01 will be printed:
#
# Excited State    1 (1 A):   0.13337 au   341.63 nm f = 1.0806
#   Sums of squares: Xssq =  1.007517e+00; Yssq =  7.516699e-03; Xssq - Yssq =  1.000000e+00
#      99a  -> 102a     0.205292 ( 4.214%)
#     100a  -> 101a     0.961035 (92.359%)
#
#
# ******************************************************************************************
# **********                               WARNING                                **********
# **********       The names of excited state variables changed between 1.5       **********
# **********     and 1.6. For a quick solution, remove the symmetry specifier     **********
# **********   from the variable name. For full details, see 'Notes on Psivars'   **********
# **********                        in the documentation.                         **********
# ******************************************************************************************

# %%
mu_debye = np.sqrt((mu[0][0] ** 2) + (mu[0][1] ** 2) + (mu[0][2] ** 2)) / 0.393456

print(f' TDM_vec = {mu} au')
print(f'TDM_mag = {mu_debye} Debye')
# Out:
#  TDM_vec = [array([-3.33569986,  1.01294496,  0.02343386])] au
# TDM_mag = 8.860424169807327 Debye
